# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import requests
import warnings 
import re
from bs4 import BeautifulSoup
warnings.filterwarnings("ignore")

# %% [markdown]
# ## “How does qualification level influence salary distribution in government job listings?”

# %% [markdown]
# ## 1️⃣Raw Data Structure
#
# ### Initially dataset contained:
#
# ##### Observed that salary column contained mixed formats (single value, range, “No Details”), and title column combined organization and role information.
#
# |Column |	Description|
# |:--|:--|
# |title	|Full job listing title|
# |link|	Job detail URL|
# |job_type	|Government / etc
# |qualification	|Raw qualification text
# |salary	|Raw salary string

# %%
df = pd.read_csv("raw_job_data.csv")
df.head()
# Out:
#                                                title  \
# 0  South Indian Bank Recruitment 2026 - Junior Of...
# 1  CSIR-National Aerospace Laboratories Recruitme...
# 2  Fertilizer Corporation of India Limited (FCIL)...
# 3  Arunachal Pradesh Public Service Commission Re...
# 4  Hindustan Petroleum Corporation Limited (HPCL)...
#
#                                                 link    Job Type  \
# 0   https://www.jobkaka.com/sib-junior-officer-post/  Government
# 1  https://www.jobkaka.com/csir-nal-project-assoc...  Government
# 2  https://www.jobkaka.com/fcil-young-professiona...  Government
# 3  https://www.jobkaka.com/appsc-assistant-profes...  Government
# 4  https://www.jobkaka.com/hpcl-graduate-apprenti...  Government
#
#   Qualification             Salary
# 0      Graduate        Rs.756000/-
# 1      Graduate   Rs.25000-25000/-
# 2      Graduate   Rs.30000-60000/-
# 3      Master's  Rs.57700-182400/-
# 4      Graduate   Rs.25000-25000/-

# %% [markdown]
# ## 2️⃣ Data Cleaning & Feature Engineering
#
# The raw dataset required structured cleaning and transformation to enable meaningful analytical insights. Below are the transformations performed:
#
# ---

# %% [markdown]
# ### 🔹 1. Salary Cleaning & Normalization
#
# The original `salary` column contained:
#
# - Single salary values (e.g., Rs. 40,000/-)
# - Salary ranges (e.g., Rs. 30,000–60,000/-)
# - Missing values ("No Details")
# - Mixed annual and monthly salary formats
#
# #### Transformations Performed:
#
# - Extracted numeric values using Regular Expressions (Regex).
# - Created:
#   - `salary_minimum`
#   - `salary_maximum`
# - For single values → assigned same value to both min and max.
# - Converted missing values to `NULL`.
# - Identified annual salaries using a heuristic rule (`salary > 200000`) and converted them to monthly values.
# - Created additional features:
#   - `salary_range` = salary_maximum − salary_minimum
#   - `salary_band` (Low / Medium / High)
#
# > Salary normalization was required because the raw dataset contained mixed annual and monthly salary formats, which distorted the overall statistical distribution.
#
# ---

# %%
# we start with Salary column
# -------------------------------------
df["Salary"].sample(20)
# Out:
# 689            No Details
# 63      Rs.56100-208700/-
# 49       Rs.28740-72110/-
# 307     Rs.97220-209445/-
# 577    Rs.160000-160000/-
# 677            No Details
# 813            No Details
# 854            No Details
# 599            No Details
# 919             Rs.9000/-
# 302     Rs.44900-208700/-
# 164      Rs.12300-12300/-
# 372            Rs.10000/-
# 305      Rs.12000-12000/-
# 206      Rs.15600-39100/-
# 403     Rs.78800-209200/-
# 549            No Details
# 532      Rs.31000-31000/-
# 624            Rs.45000/-
# 82             No Details
# Name: Salary, dtype: object

# %%
salary_string = list(df["Salary"])
sal_min = []
sal_max = []
for s in salary_string:
    num = re.findall(r"\d+", s)
    # print(s," : ", numbers)
    if len(num) == 2:
        sal_min.append(num[0])
        sal_max.append(num[1])
    elif len(num) == 1:
        sal_min.append(num[0])
        sal_max.append(num[0])
    elif len(num) == 0:
        sal_min.append(None)
        sal_max.append(None)

# %%
df["salary_minimum"] = sal_min
df["salary_maximum"] = sal_max

# %%
df.head()
# Out:
#                                                title  \
# 0  South Indian Bank Recruitment 2026 - Junior Of...
# 1  CSIR-National Aerospace Laboratories Recruitme...
# 2  Fertilizer Corporation of India Limited (FCIL)...
# 3  Arunachal Pradesh Public Service Commission Re...
# 4  Hindustan Petroleum Corporation Limited (HPCL)...
#
#                                                 link    Job Type  \
# 0   https://www.jobkaka.com/sib-junior-officer-post/  Government
# 1  https://www.jobkaka.com/csir-nal-project-assoc...  Government
# 2  https://www.jobkaka.com/fcil-young-professiona...  Government
# 3  https://www.jobkaka.com/appsc-assistant-profes...  Government
# 4  https://www.jobkaka.com/hpcl-graduate-apprenti...  Government
#
#   Qualification             Salary salary_minimum salary_maximum
# 0      Graduate        Rs.756000/-         756000         756000
# 1      Graduate   Rs.25000-25000/-          25000          25000
# 2      Graduate   Rs.30000-60000/-          30000          60000
# 3      Master's  Rs.57700-182400/-          57700         182400
# 4      Graduate   Rs.25000-25000/-          25000          25000

# %%
# Checking for the data type of Integer columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1028 entries, 0 to 1027
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           1028 non-null   object
#  1   link            1028 non-null   object
#  2   Job Type        1028 non-null   object
#  3   Qualification   1028 non-null   object
#  4   Salary          1028 non-null   object
#  5   salary_minimum  667 non-null    object
#  6   salary_maximum  667 non-null    object
# dtypes: object(7)
# memory usage: 56.3+ KB

# %%
# The Numeric values from the object 
df["salary_minimum"] = pd.to_numeric(df["salary_minimum"], errors="coerce")
df["salary_maximum"] = pd.to_numeric(df["salary_maximum"], errors="coerce")

# %%
df.head()
# Out:
#                                                title  \
# 0  South Indian Bank Recruitment 2026 - Junior Of...
# 1  CSIR-National Aerospace Laboratories Recruitme...
# 2  Fertilizer Corporation of India Limited (FCIL)...
# 3  Arunachal Pradesh Public Service Commission Re...
# 4  Hindustan Petroleum Corporation Limited (HPCL)...
#
#                                                 link    Job Type  \
# 0   https://www.jobkaka.com/sib-junior-officer-post/  Government
# 1  https://www.jobkaka.com/csir-nal-project-assoc...  Government
# 2  https://www.jobkaka.com/fcil-young-professiona...  Government
# 3  https://www.jobkaka.com/appsc-assistant-profes...  Government
# 4  https://www.jobkaka.com/hpcl-graduate-apprenti...  Government
#
#   Qualification             Salary  salary_minimum  salary_maximum
# 0      Graduate        Rs.756000/-        756000.0        756000.0
# 1      Graduate   Rs.25000-25000/-         25000.0         25000.0
# 2      Graduate   Rs.30000-60000/-         30000.0         60000.0
# 3      Master's  Rs.57700-182400/-         57700.0        182400.0
# 4      Graduate   Rs.25000-25000/-         25000.0         25000.0

# %% [markdown]
# ####  We got to know the values are Less than

# %%
df[df["salary_minimum"] < 1000][["title", "salary_minimum", "salary_maximum"]]
# Out:
#                                                  title  salary_minimum  \
# 29   Motilal Nehru College (Evening), University of...            10.0
# 65   Central Sanskrit University (CSU), New Delhi R...            10.0
# 118  Maitreyi College (University of Delhi), New De...            10.0
# 133  All India Institute of Medical Sciences, Jammu...            13.0
# 429  Tata Institute of Fundamental Research Recruit...            10.0
# 475  Meghalaya Public Service Commission Recruitmen...            12.0
# 536  Sikkim Public Service Commission Recruitment 2...            15.0
# 615  Bihar Police Recruitment 2025 - Sub Inspector ...             6.0
# 821  High Court of Manipur Recruitment - Assistant ...           273.0
#
#      salary_maximum
# 29             10.0
# 65             10.0
# 118            10.0
# 133            13.0
# 429            10.0
# 475            12.0
# 536            15.0
# 615             6.0
# 821           273.0

# %%
# checking for the values above 200000 (because governament jobs do not goes above that margin.)
salary_string = list(df["Salary"])
for s in salary_string:
    numbers = re.findall(r"\d+", s)
    if len(numbers) == 1:
        if int(numbers[0]) > 200000:
            print(numbers)
# Out:
# ['756000']
# ['3000000']
# ['2815000']
# ['1080000']
# ['1700000']
# ['2600000']
# ['1295000']
# ['7000000']
# ['8000000']
# ['208700']
# ['280000']
# ['208700']
# ['280000']
# ['215900']
# ['280000']
# ['280000']
# ['300000']
# ['2250000']
# ['3600000']
# ['208700']
# ['201213']
# ['1600000']
# ['240000']
# ['1600000']
# ['700000']
# ['240000']
# ['208700']
# ['220000']

# %%
# convert the salaries from the annully mixed to montly once.

df["salary_type"] = df["salary_minimum"].apply(lambda x: "annual" if x and x > 200000 else "monthly")

# %%
df.loc[df["salary_type"] == "annual", "salary_minimum"] /= 12
df.loc[df["salary_type"] == "annual", "salary_maximum"] /= 12

# %%
df.head()
# Out:
#                                                title  \
# 0  South Indian Bank Recruitment 2026 - Junior Of...
# 1  CSIR-National Aerospace Laboratories Recruitme...
# 2  Fertilizer Corporation of India Limited (FCIL)...
# 3  Arunachal Pradesh Public Service Commission Re...
# 4  Hindustan Petroleum Corporation Limited (HPCL)...
#
#                                                 link    Job Type  \
# 0   https://www.jobkaka.com/sib-junior-officer-post/  Government
# 1  https://www.jobkaka.com/csir-nal-project-assoc...  Government
# 2  https://www.jobkaka.com/fcil-young-professiona...  Government
# 3  https://www.jobkaka.com/appsc-assistant-profes...  Government
# 4  https://www.jobkaka.com/hpcl-graduate-apprenti...  Government
#
#   Qualification             Salary  salary_minimum  salary_maximum
# 0      Graduate        Rs.756000/-        756000.0        756000.0
# 1      Graduate   Rs.25000-25000/-         25000.0         25000.0
# 2      Graduate   Rs.30000-60000/-         30000.0         60000.0
# 3      Master's  Rs.57700-182400/-         57700.0        182400.0
# 4      Graduate   Rs.25000-25000/-         25000.0         25000.0

# %%
# creating the feaure salary band

def salary_band(x):
    if pd.isna(x):
        return np.nan
    elif x < 30000:
        return "Low"
    elif x < 70000:
        return "Medium"
    elif x < 150000:
        return "High"
    else:
        return "Very High"

df["salary_band"] = df["salary_minimum"].apply(salary_band)

# %%
df[["salary_minimum","salary_maximum"]]
# Out:
#       salary_minimum  salary_maximum
# 0             63,000          63,000
# 1             25,000          25,000
# 2             30,000          60,000
# 3             57,700         182,400
# 4             25,000          25,000
# ...              ...             ...
# 1023             NaN             NaN
# 1024             NaN             NaN
# 1025             NaN             NaN
# 1026             NaN             NaN
# 1027         150,000         150,000
#
# [1019 rows x 2 columns]

# %%
df["salary_range"] = df["salary_maximum"] - df["salary_minimum"]

# %%
df.isnull().sum()
# Out:
# Job Type                 0
# salary_minimum         361
# salary_maximum         361
# salary_band            361
# salary_range           361
# qualification_level      0
# sector                   0
# role_category            0
# dtype: int64

# %%
df["salary_minimum"].isna().sum()
# Out:
# np.int64(361)

# %%
df.head()
# Out:
#      Job Type  salary_minimum  salary_maximum salary_band  salary_range  \
# 0  Government        756000.0        756000.0    null_val           0.0
# 1  Government         25000.0         25000.0         Low           0.0
# 2  Government         30000.0         60000.0      Medium       30000.0
# 3  Government         57700.0        182400.0      Medium      124700.0
# 4  Government         25000.0         25000.0         Low           0.0
#
#   qualification_level              sector role_category
# 0       undergraduate             Banking       Officer
# 1       undergraduate  Government General     Associate
# 2       undergraduate                 PSU         Other
# 3        postgraduate    Government Admin      Academic
# 4       undergraduate                 PSU      Engineer

# %% [markdown]
# #### we can observe the Qualification Column.

# %% [markdown]
# ### 🔹 2. Qualification Standardization
#
# The `qualification` column contained multiple textual variations such as:
#
# - Graduate
# - Graduation
# - Bachelor Degree
# - Master's
# - Postgraduate
# - Diploma
# - 10th / 12th
#
# #### Transformations Performed:
#
# - Converted text to lowercase.
# - Applied keyword-based mapping to standardize education levels.
# - Created a new column: `qualification_level`, categorized into:
#
#   - `undergraduate`
#   - `postgraduate`
#   - `doctorate`
#   - `diploma`
#   - `school_level`
#   - `other`
#
# Priority rules were applied to prevent misclassification (e.g., “postgraduate” incorrectly matching “graduate”).
#
# ---

# %%
df["Qualification"].value_counts().head(50)
# Out:
# Qualification
# Graduate                                                   455
# Master's                                                   125
# Postgraduate                                                20
# Bachelor Degree                                             17
# Graduation                                                  13
# Degree                                                      12
# Doctorate                                                   11
# Not Applicable                                               9
# Intermediate (12th)                                          8
# Diploma                                                      7
# Professional                                                 7
# Bachelors degree                                             7
# Bachelor's                                                   6
# Post Graduate                                                6
# Any Degree                                                   6
# graduate                                                     5
# ITI                                                          5
# BE/ BTech                                                    4
# Bachelors Degree                                             4
# Diploma in Civil Engineering                                 4
# Intermediate                                                 4
# Bachelor Degree in Any Stream                                4
# BE / BTech                                                   3
# 12th Pass                                                    3
# 12th                                                         3
# MBBS                                                         3
# B.E. / B.Tech                                                3
# Bachelor's Degree                                            3
# B.E. / B.Tech.                                               2
# Graduate degree                                              2
# Law Graduate                                                 2
# Graduates                                                    2
# ITI in related trade                                         2
# BSc                                                          2
# Member of The Institute of Company Secretaries of India      2
# 10+2                                                         2
# 10th                                                         2
# B.Tech                                                       2
# Engineering Degree                                           2
# BE / B.Tech                                                  2
# B.Sc Nursing                                                 2
# BE/BTech                                                     2
# LLB                                                          2
# B.Tech degree                                                2
# Diploma in Engineering                                       2
# Diploma (Engg)                                               2
# Doctoral                                                     2
# Masters Degree                                               2
# Engineering Graduate                                         2
# Degree in Civil Engineering                                  2
# Name: count, dtype: int64

# %%
df["qualification_clean"] = df["Qualification"].str.lower()

# %%
df["qualification_clean"].value_counts()
# Out:
# qualification_clean
# graduate                                                                                        460
# master's                                                                                        125
# postgraduate                                                                                     20
# bachelor degree                                                                                  17
# degree                                                                                           13
#                                                                                                ...
# be / btech in electronics/ instrumentation and min 1 year experience                              1
# bsc nursing                                                                                       1
# bachelors degree in engineering or post-graduation in geoscience and min 20 years experience      1
# m.e. /m.tech.                                                                                     1
# iti/bsc                                                                                           1
# Name: count, Length: 274, dtype: int64

# %%
df["qualification_level"] = ["other"]*1028

# %%
# Doctorate
df.loc[df["qualification_clean"].str.contains("phd|doctorate|doctoral", na=False),
       "qualification_level"] = "doctorate"
# Undergraduate
df.loc[df["qualification_clean"].str.contains("bachelor|graduate|b.tech|btech|b.e|bsc|degree|engineering", na=False),
       "qualification_level"] = "undergraduate"
# Postgraduate
df.loc[df["qualification_clean"].str.contains("master|postgraduate|post graduate|mba|m.tech", na=False),
       "qualification_level"] = "postgraduate"
# Diploma
df.loc[df["qualification_clean"].str.contains("diploma|iti", na=False),
       "qualification_level"] = "diploma"
# School
df.loc[df["qualification_clean"].str.contains("10th|12th|intermediate|10\\+2", na=False),
       "qualification_level"] = "school_level"

# %%
df["qualification_level"].value_counts()
# Out:
# qualification_level
# undergraduate    648
# postgraduate     183
# other             89
# diploma           46
# school_level      46
# doctorate         16
# Name: count, dtype: int64

# %%
# we do verify the column match with classification

df.loc[df["qualification_level"]=="other"][["qualification_clean","qualification_level"]]
# Out:
#           qualification_clean qualification_level
# 69               professional               other
# 265              professional               other
# 298              professional               other
# 423              professional               other
# 434             not specified               other
# ...                       ...                 ...
# 1004               graduation               other
# 1008                 gate/net               other
# 1015                 (b. ed.)               other
# 1017                        0               other
# 1018  b. tech./b. e or m. sc.               other
#
# [89 rows x 2 columns]

# %%
df.head()
# Out:
#                                                title  \
# 0  South Indian Bank Recruitment 2026 - Junior Of...
# 1  CSIR-National Aerospace Laboratories Recruitme...
# 2  Fertilizer Corporation of India Limited (FCIL)...
# 3  Arunachal Pradesh Public Service Commission Re...
# 4  Hindustan Petroleum Corporation Limited (HPCL)...
#
#                                                 link    Job Type  \
# 0   https://www.jobkaka.com/sib-junior-officer-post/  Government
# 1  https://www.jobkaka.com/csir-nal-project-assoc...  Government
# 2  https://www.jobkaka.com/fcil-young-professiona...  Government
# 3  https://www.jobkaka.com/appsc-assistant-profes...  Government
# 4  https://www.jobkaka.com/hpcl-graduate-apprenti...  Government
#
#   Qualification             Salary  salary_minimum  salary_maximum  \
# 0      Graduate        Rs.756000/-        756000.0        756000.0
# 1      Graduate   Rs.25000-25000/-         25000.0         25000.0
# 2      Graduate   Rs.30000-60000/-         30000.0         60000.0
# 3      Master's  Rs.57700-182400/-         57700.0        182400.0
# 4      Graduate   Rs.25000-25000/-         25000.0         25000.0
#
#   salary_band  salary_range qualification_clean qualification_level
# 0        High           0.0            graduate       undergraduate
# 1         Low           0.0            graduate       undergraduate
# 2      Medium       30000.0            graduate       undergraduate
# 3      Medium      124700.0            master's        postgraduate
# 4         Low           0.0            graduate       undergraduate

# %% [markdown]
# ### 🔹 3. Title-Based Feature Engineering
#
# The `title` column originally combined organization and job role information.
#
# Example format:
#
# #### Transformations Performed:
#
# - Split title into:
#   - `organization_part`
#   - `role_part`
# - Extracted:
#   - `sector` (e.g., Banking, Education, Healthcare, PSU, Government Admin)
#   - `role_category` (e.g., Officer, Engineer, Assistant, Managerial, Research, Academic)
#
# Keyword-based mapping with priority hierarchy was used to ensure accurate classification.
#
# ---

# %% [markdown]
# ##### Job Title contain the values like [ Organization_name - year - Job_Title ]

# %%
df["has_dash"] = df["title"].str.contains(" - ")
df["has_dash"].value_counts()
# Out:
# has_dash
# True    1028
# Name: count, dtype: int64

# %%
df[["organization_part", "role_part"]] = df_old["title"].str.split(" - ", n=1, expand=True)

# %%
from collections import Counter

org_words = []
role_words = []

for title in df["organization_part"]:
    words = re.findall(r"[A-Za-z]+", title.lower())
    org_words.extend(words)

for title in df["role_part"]:
    words = re.findall(r"[A-Za-z]+", title.lower())
    role_words.extend(words)

# %%
org_counts = Counter(org_words)
role_counts = Counter(role_words)

# %%
org_counts.most_common(30)
# Out:
# [('recruitment', 1038),
#  ('of', 308),
#  ('limited', 225),
#  ('institute', 193),
#  ('india', 133),
#  ('national', 124),
#  ('and', 108),
#  ('bank', 100),
#  ('commission', 97),
#  ('service', 92),
#  ('corporation', 82),
#  ('public', 81),
#  ('indian', 79),
#  ('technology', 71),
#  ('research', 63),
#  ('university', 58),
#  ('pradesh', 53),
#  ('central', 48),
#  ('development', 45),
#  ('board', 38),
#  ('state', 37),
#  ('court', 36),
#  ('medical', 36),
#  ('high', 35),
#  ('selection', 33),
#  ('for', 33),
#  ('sciences', 31),
#  ('power', 31),
#  ('company', 30),
#  ('delhi', 26)]

# %%
role_counts.most_common(30)
# Out:
# [('jobs', 1028),
#  ('and', 190),
#  ('assistant', 175),
#  ('other', 147),
#  ('officer', 129),
#  ('various', 123),
#  ('manager', 113),
#  ('junior', 91),
#  ('engineer', 74),
#  ('project', 68),
#  ('research', 61),
#  ('associate', 53),
#  ('senior', 51),
#  ('graduate', 50),
#  ('i', 44),
#  ('apprentice', 44),
#  ('trainee', 44),
#  ('grade', 40),
#  ('fellow', 40),
#  ('medical', 38),
#  ('posts', 37),
#  ('general', 33),
#  ('executive', 32),
#  ('technical', 31),
#  ('civil', 30),
#  ('iii', 25),
#  ('deputy', 25),
#  ('engineering', 24),
#  ('teacher', 24),
#  ('ii', 23)]

# %%
def extract_sector(org):
    org = org.lower()
    
    if "bank" in org:
        return "Banking"
    elif "university" in org or "institute" in org:
        return "Education"
    elif "medical" in org or "hospital" in org:
        return "Healthcare"
    elif "court" in org:
        return "Judiciary"
    elif "power" in org:
        return "Energy"
    elif "corporation" in org:
        return "PSU"
    elif "commission" in org or "board" in org:
        return "Government Admin"
    elif "technology" in org or "research" in org:
        return "Technical/Research"
    else:
        return "Government General"

# %%
df["sector"] = df["organization_part"].apply(extract_sector)

# %%
def extract_role(role):
    role = role.lower()
    
    if "professor" in role or "teacher" in role:
        return "Academic"
    elif "research" in role or "fellow" in role:
        return "Research"
    elif "engineer" in role or "engineering" in role:
        return "Engineer"
    elif "manager" in role or "executive" in role or "deputy" in role:
        return "Managerial"
    elif "officer" in role:
        return "Officer"
    elif "assistant" in role:
        return "Assistant"
    elif "apprentice" in role or "trainee" in role:
        return "Entry Level"
    elif "associate" in role:
        return "Associate"
    elif "medical" in role:
        return "Medical"
    else:
        return "Other"

# %%
df["role_category"] = df["role_part"].apply(extract_role)

# %%
df["role_category"].value_counts()
# Out:
# role_category
# Other          354
# Managerial     142
# Officer        117
# Assistant       93
# Engineer        91
# Entry Level     79
# Research        65
# Academic        43
# Associate       36
# Medical          8
# Name: count, dtype: int64

# %%
df["sector"].value_counts()
# Out:
# sector
# Government General    375
# Education             243
# Government Admin      133
# Banking               106
# PSU                    65
# Judiciary              35
# Energy                 31
# Technical/Research     24
# Healthcare             16
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                title  \
# 0  South Indian Bank Recruitment 2026 - Junior Of...
# 1  CSIR-National Aerospace Laboratories Recruitme...
# 2  Fertilizer Corporation of India Limited (FCIL)...
# 3  Arunachal Pradesh Public Service Commission Re...
# 4  Hindustan Petroleum Corporation Limited (HPCL)...
#
#                                                 link    Job Type  \
# 0   https://www.jobkaka.com/sib-junior-officer-post/  Government
# 1  https://www.jobkaka.com/csir-nal-project-assoc...  Government
# 2  https://www.jobkaka.com/fcil-young-professiona...  Government
# 3  https://www.jobkaka.com/appsc-assistant-profes...  Government
# 4  https://www.jobkaka.com/hpcl-graduate-apprenti...  Government
#
#   Qualification             Salary  salary_minimum  salary_maximum  \
# 0      Graduate        Rs.756000/-        756000.0        756000.0
# 1      Graduate   Rs.25000-25000/-         25000.0         25000.0
# 2      Graduate   Rs.30000-60000/-         30000.0         60000.0
# 3      Master's  Rs.57700-182400/-         57700.0        182400.0
# 4      Graduate   Rs.25000-25000/-         25000.0         25000.0
#
#   salary_band  salary_range qualification_clean qualification_level  has_dash  \
# 0        High           0.0            graduate       undergraduate      True
# 1         Low           0.0            graduate       undergraduate      True
# 2      Medium       30000.0            graduate       undergraduate      True
# 3      Medium      124700.0            master's        postgraduate      True
# 4         Low           0.0            graduate       undergraduate      True
#
#                                    organization_part  \
# 0                 South Indian Bank Recruitment 2026
# 1  CSIR-National Aerospace Laboratories Recruitme...
# 2  Fertilizer Corporation of India Limited (FCIL)...
# 3  Arunachal Pradesh Public Service Commission Re...
# 4  Hindustan Petroleum Corporation Limited (HPCL)...
#
#                                            role_part              sector  \
# 0                                Junior Officer Jobs             Banking
# 1                           Project Associate-I Jobs  Government General
# 2  Young Professional (Finance, Company Secretary...                 PSU
# 3     Assistant Professor (Various Disciplines) Jobs    Government Admin
# 4  Graduate Apprentice (Engineering) - Civil / Me...                 PSU
#
#   role_category
# 0       Officer
# 1     Associate
# 2         Other
# 3      Academic
# 4      Engineer

# %% [markdown]
# ### 3️⃣ Data Cleaning

# %% [markdown]
# 1️⃣ Demand analysis And Fix structural errors (unit mismatch)
# 2️⃣ Fix extreme misparsed values
# 3️⃣ Then handle missing values
# 4️⃣ Then handle statistical outliers

# %%
df = pd.read_csv("Job_data_cleaned_1.csv")
df.head()
# Out:
#      Job Type  salary_minimum  salary_maximum salary_band  salary_range  \
# 0  Government          63,000          63,000      Medium             0
# 1  Government          25,000          25,000         Low             0
# 2  Government          30,000          60,000      Medium        30,000
# 3  Government          57,700         182,400      Medium       124,700
# 4  Government          25,000          25,000         Low             0
#
#   qualification_level              sector role_category
# 0       undergraduate             Banking       Officer
# 1       undergraduate  Government General     Associate
# 2       undergraduate                 PSU         Other
# 3        postgraduate    Government Admin      Academic
# 4       undergraduate                 PSU      Engineer

# %%
df.shape
# Out:
# (1019, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1019 entries, 0 to 1018
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Job Type             1019 non-null   object
#  1   salary_minimum       658 non-null    float64
#  2   salary_maximum       658 non-null    float64
#  3   salary_band          658 non-null    object
#  4   salary_range         658 non-null    float64
#  5   qualification_level  1019 non-null   object
#  6   sector               1019 non-null   object
#  7   role_category        1019 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 63.8+ KB

# %%
# Making 
df["salary_minimum"] = df["salary_minimum"].round(0)
df["salary_maximum"] = df["salary_maximum"].round(0)

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
df.describe()
# Out:
#        salary_minimum  salary_maximum  salary_range
# count             658             658           658
# mean           52,878          81,767        28,889
# std            50,886          73,626        51,966
# min             1,000           1,000             0
# 25%            25,000          30,640             0
# 50%            40,000          56,100             0
# 75%            65,000         120,940        32,250
# max           666,667         666,667       415,000

# %%
df.columns
# Out:
# Index(['Job Type', 'salary_minimum', 'salary_maximum', 'salary_band',
#        'salary_range', 'qualification_level', 'sector', 'role_category'],
#       dtype='object')

# %% [markdown]
# #### The following columns have no use for the analysis and only used for feature extraction.

# %%
df.drop(columns=['title', 'link', 'Qualification', 'Salary',
                 'qualification_clean','has_dash', 'organization_part', 'role_part'], inplace=True)

# %%
df.isna().sum()
# Out:
# Job Type                 0
# salary_minimum         361
# salary_maximum         361
# salary_band            361
# salary_range           361
# qualification_level      0
# sector                   0
# role_category            0
# dtype: int64

# %%
outliers = df.loc[[29,65,118,133,429,475,536,615,821],:]
outliers
# Out:
#        Job Type  salary_minimum  salary_maximum salary_band  salary_range  \
# 29   Government              10              10         Low             0
# 65   Government              10              10         Low             0
# 118  Government              10              10         Low             0
# 133  Government              13              13         Low             0
# 429  Government              10              10         Low             0
# 475  Government              12              12         Low             0
# 536  Government              15              15         Low             0
# 615  Government               6               6         Low             0
# 821  Government             273             273         Low             0
#
#     qualification_level              sector role_category
# 29        undergraduate           Education       Officer
# 65        undergraduate           Education         Other
# 118        postgraduate           Education      Academic
# 133       undergraduate           Education      Engineer
# 429       undergraduate           Education       Officer
# 475       undergraduate    Government Admin       Officer
# 536       undergraduate    Government Admin         Other
# 615        postgraduate  Government General         Other
# 821       undergraduate           Judiciary     Assistant

# %%
df = df.drop(index=[29,65,118,133,429,475,536,615,821])

# %%
df.shape
# Out:
# (1019, 8)

# %% [markdown]
# ### 🔹 Final Analytical Dataset
#
# After cleaning and feature engineering, the dataset included:
#
# - `qualification_level`
# - `salary_minimum`
# - `salary_maximum`
# - `salary_range`
# - `salary_band`
# - `sector`
# - `role_category`
#
# These engineered features enabled multi-dimensional analysis across education, role type, sector, and compensation levels.

# %% [markdown]
# ### Save Cleaned Dataset
# #### As it is getting more Cleaning steps involved like droping missing values and Outliers from the data, we save it.

# %%
df.to_csv("Job_data_cleaned_1.csv",index=False)

# %%
df = pd.read_csv("Job_data_cleaned_1.csv")

# %% [markdown]
# #### pure data which have no null values.

# %% [markdown]
# ## Handling Missing values and Outliers in Numerical columns.

# %% [markdown]
# ### Missing Values Handling

# %%
import missingno as msno

# %%
msno.matrix(df)

# %% [markdown]
# #### Approximately 35% of job listings did not disclose salary information.
# - These rows were retained for demand distribution analysis
# - but excluded from salary-specific analysis.

# %%
per = (361/1019)*100
print(f"Total {per} of values are missing from the salary section.")
# Out:
# Total 35.426889106967614 of values are missing from the salary section.

# %% [markdown]
# #### 1. Droping the missing values

# %%
df_salary = df[df["salary_minimum"].notna()].copy()
df_salary # salary
# Out:
#         Job Type  salary_minimum  salary_maximum salary_band  salary_range  \
# 0     Government          63,000          63,000      Medium             0
# 1     Government          25,000          25,000         Low             0
# 2     Government          30,000          60,000      Medium        30,000
# 3     Government          57,700         182,400      Medium       124,700
# 4     Government          25,000          25,000         Low             0
# ...          ...             ...             ...         ...           ...
# 996   Government          44,900         142,400      Medium        97,500
# 999   Government          31,000          31,000      Medium             0
# 1000  Government          37,000          37,000      Medium             0
# 1005  Government          78,800         209,200        High       130,400
# 1018  Government         150,000         150,000   Very High             0
#
#      qualification_level              sector role_category
# 0          undergraduate             Banking       Officer
# 1          undergraduate  Government General     Associate
# 2          undergraduate                 PSU         Other
# 3           postgraduate    Government Admin      Academic
# 4          undergraduate                 PSU      Engineer
# ...                  ...                 ...           ...
# 996        undergraduate          Healthcare       Officer
# 999                other           Education      Research
# 1000       undergraduate           Education      Engineer
# 1005       undergraduate  Government General    Managerial
# 1018        postgraduate  Government General         Other
#
# [658 rows x 8 columns]

# %%
fig,axes = plt.subplots(1,2,figsize = (12,5))

sns.kdeplot(data=df_salary["salary_minimum"],ax=axes[0],fill=True) 
sns.kdeplot(data=df["salary_minimum"],ax=axes[1],fill=True)

axes[0].set_title("KDE plot with Drop NA")
axes[1].set_title("KDE plot Original")

axes[0].set_xlabel("Monthly Salary")
axes[0].set_ylabel("Density")

axes[1].set_xlabel("Monthly Salary")
axes[1].set_ylabel("Density")


axes[0].legend()
axes[1].legend()
plt.show()

# %% [markdown]
# #### 2. Handling data with missing values in Data distribution Analysis.

# %% [markdown]
# ### Outliers Handling
# ---

# %%
# Minimum Salary Outliers
Q1 = df_salary["salary_minimum"].quantile(0.25)
Q3 = df_salary["salary_minimum"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# %%
outliers = df_salary[(df_salary["salary_minimum"] < lower) | (df_salary["salary_minimum"] > upper)]

# %%
outliers.head()
# Out:
#        Job Type  salary_minimum  salary_maximum salary_band  salary_range  \
# 17   Government         200,000         300,000   Very High       100,000
# 47   Government         156,500         173,860   Very High        17,360
# 50   Government         177,500         177,500   Very High             0
# 72   Government         142,400         142,400        High             0
# 107  Government         156,500         210,800   Very High        54,300
#
#     qualification_level              sector role_category
# 17        undergraduate  Government General    Managerial
# 47         postgraduate             Banking    Managerial
# 50         postgraduate           Education       Officer
# 72        undergraduate           Education       Officer
# 107       undergraduate              Energy    Managerial

# %%
# Maximum Salary outliers

Q1 = df_salary["salary_maximum"].quantile(0.25)
Q3 = df_salary["salary_maximum"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers_1 = df_salary[(df_salary["salary_maximum"] < lower) | (df_salary["salary_maximum"] > upper)]

# %%
outliers_1
# Out:
#        Job Type  salary_minimum  salary_maximum salary_band  salary_range  \
# 17   Government         200,000         300,000   Very High       100,000
# 93   Government          70,000         260,000        High       190,000
# 144  Government         100,000         260,000        High       160,000
# 306  Government          85,000         500,000        High       415,000
# 430  Government         100,000         260,000        High       160,000
# 494  Government         583,333         583,333   Very High             0
# 505  Government         666,667         666,667   Very High             0
# 699  Government         100,000         260,000        High       160,000
# 749  Government         300,000         300,000   Very High             0
# 993  Government         120,000         280,000        High       160,000
#
#     qualification_level              sector role_category
# 17        undergraduate  Government General    Managerial
# 93        undergraduate  Government General    Managerial
# 144       undergraduate  Government General         Other
# 306        postgraduate             Banking       Officer
# 430        postgraduate  Government General    Managerial
# 494       undergraduate             Banking       Officer
# 505       undergraduate  Government General       Officer
# 699       undergraduate  Government General         Other
# 749       undergraduate                 PSU    Managerial
# 993       undergraduate  Government General    Managerial

# %%
sns.kdeplot(np.log1p(df_salary["salary_minimum"]))
# Out:
# <Axes: xlabel='salary_minimum', ylabel='Density'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data=df_salary, x="qualification_level", y="salary_minimum")
plt.show()

# %% [markdown]
# ### Two typed Data

# %%
upper_limit = df_salary["salary_minimum"].quantile(0.99)
df_trimmed = df_salary[df_salary["salary_minimum"] <= upper_limit].copy()

# %%
df_trimmed
# Out:
#         Job Type  salary_minimum  salary_maximum salary_band  salary_range  \
# 0     Government          63,000          63,000      Medium             0
# 1     Government          25,000          25,000         Low             0
# 2     Government          30,000          60,000      Medium        30,000
# 3     Government          57,700         182,400      Medium       124,700
# 4     Government          25,000          25,000         Low             0
# ...          ...             ...             ...         ...           ...
# 996   Government          44,900         142,400      Medium        97,500
# 999   Government          31,000          31,000      Medium             0
# 1000  Government          37,000          37,000      Medium             0
# 1005  Government          78,800         209,200        High       130,400
# 1018  Government         150,000         150,000   Very High             0
#
#      qualification_level              sector role_category
# 0          undergraduate             Banking       Officer
# 1          undergraduate  Government General     Associate
# 2          undergraduate                 PSU         Other
# 3           postgraduate    Government Admin      Academic
# 4          undergraduate                 PSU      Engineer
# ...                  ...                 ...           ...
# 996        undergraduate          Healthcare       Officer
# 999                other           Education      Research
# 1000       undergraduate           Education      Engineer
# 1005       undergraduate  Government General    Managerial
# 1018        postgraduate  Government General         Other
#
# [652 rows x 8 columns]

# %%
# to save updated data
df.to_csv("Job_Data_cleaned_1.csv",index=False)

# %%
df_trimmed.to_csv("Job_Data_Trimmed.csv",index=False)
